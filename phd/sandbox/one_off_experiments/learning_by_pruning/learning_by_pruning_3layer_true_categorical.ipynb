# %% [markdown]
# # Learning by Pruning — 3-Layer Network (LTU)
#
# Same experiment as the 2-layer version, but with **two hidden layers**. No weight updates — only forward passes, utility tracking, and pruning. Uses **LTU activation**.
#
# **Utility function**:
# - **Output layer**: v1 — LOO utility shifted by per-output min (all non-negative)
# - **Hidden layer propagation**: each upper-layer unit distributes its utility among its positively-contributing inputs, proportional to contribution magnitude

# %% [markdown]
# Script should have options for:
#     - All global hyperparams except for trace decay and n steps
#     - Which utility function to use (output and input combined)
#     - Whether to prune h1
#     - Whether to prune h2

# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets

from phd.jax_core.models import ltu

# ── Global hyperparameters ────────────────────────────────────────────
HIDDEN1_SIZE = 3200
HIDDEN2_SIZE = 10 #3200
PRUNE_EVERY = 500
PRINT_EVERY = 5_000
TRACE_DECAY = 1.0 - (1.0 / PRUNE_EVERY)
TOTAL_PRUNE_EVENTS = HIDDEN1_SIZE #+ HIDDEN2_SIZE
N_STEPS = TOTAL_PRUNE_EVENTS * PRUNE_EVERY
RESET_TRACES_ON_PRUNE = False
SEED = 260326
SCAN_UNROLL = 10
USE_IDEAL_OUTPUT_WEIGHTS = True # Only works when Hidden 2 dim is 10, and makes output weights orthogonal to each other
                                # by using an identity matrix.

# %%
# ── Load MNIST ────────────────────────────────────────────────────────
train_dataset = datasets.MNIST(root='./data', train=True, download=True)

all_images_np = train_dataset.data.numpy().reshape(-1, 784).astype(np.float32)
all_images_np = all_images_np / 255.0
all_labels_np = train_dataset.targets.numpy()

INPUT_SIZE = 784
OUTPUT_SIZE = 10
print(f'Loaded {len(all_labels_np)} training images')
# Out:
# Loaded 60000 training images

# %%
# ── Initialize network weights and pruning masks ─────────────────────
key = jax.random.PRNGKey(SEED)
k1, k2, k3 = jax.random.split(key, 3)

W1 = jax.random.normal(k1, (INPUT_SIZE, HIDDEN1_SIZE)) * np.sqrt(2.0 / INPUT_SIZE)
W2 = jax.random.normal(k2, (HIDDEN1_SIZE, HIDDEN2_SIZE)) * np.sqrt(2.0 / HIDDEN1_SIZE)

if USE_IDEAL_OUTPUT_WEIGHTS:
    assert HIDDEN2_SIZE == OUTPUT_SIZE
    W3 = jnp.eye(HIDDEN2_SIZE)
else:
    W3 = jax.random.normal(k3, (HIDDEN2_SIZE, OUTPUT_SIZE)) * np.sqrt(2.0 / HIDDEN2_SIZE)


mask1 = jnp.ones(HIDDEN1_SIZE)
mask2 = jnp.ones(HIDDEN2_SIZE)
utility_trace1 = jnp.zeros(HIDDEN1_SIZE)
utility_trace2 = jnp.zeros(HIDDEN2_SIZE)

print(f'Network: {INPUT_SIZE} -> {HIDDEN1_SIZE} (LTU) -> {HIDDEN2_SIZE} (LTU) -> {OUTPUT_SIZE}')
n_params = W1.size + W2.size + W3.size
print(f'Total parameters: {n_params:,}')
# Out:
# Network: 784 -> 3200 (LTU) -> 10 (LTU) -> 10
# Total parameters: 2,540,900

# %%
# def forward(x, W1, W2, W3, mask1, mask2):
#     z1 = x @ W1
#     h1 = ltu(z1) * mask1
#     z2 = h1 @ W2
#     h2 = ltu(z2) * mask2
#     logits = h2 @ W3
#     return logits, h1, h2


# def compute_output_utility(h, W_out, logits, label):
#     """V0 utility, based on LOO effect on cross-entropy."""
#     # Counterfactual logits when each hidden unit i is removed
#     c = W_out * h[:, None]  # (in, out) — contribution of unit i to each logit
#     logits_wo = logits[None, :] - c  # (in, out)

#     # Log-probs with and without each unit
#     log_probs = jax.nn.log_softmax(logits)  # (out,)
#     log_probs_wo = jax.nn.log_softmax(logits_wo, axis=1)  # (in, out)
    
#     cross_entropy = -log_probs[label]
#     cross_entropy_wo = -log_probs_wo[:, label]
    
#     U = cross_entropy_wo - cross_entropy # (in,)
    
#     return U


# # Flip effect on cross-entropy (0->1, 1->0)
# def compute_utility_flip(h, W2, logits, label):
#     flip = 1 - 2 * h                                          # (in,)
#     logits_flip = logits[None, :] + flip[:, None] * W2        # (in, out)

#     log_probs = jax.nn.log_softmax(logits)                    # (out,)
#     log_probs_flip = jax.nn.log_softmax(logits_flip, axis=1)  # (in, out)

#     cross_entropy = -log_probs[label]                         # scalar
#     cross_entropy_flip = -log_probs_flip[:, label]            # (in,)

#     U = cross_entropy_flip - cross_entropy                    # (in,)
#     return U


# def propagate_utility(h_below, W, target_activations, U_above, mask=None):
#     """
#     Distribute utility from upper layer to lower layer.
#     Only works for LTUs.
#     """
#     # h: (in,), W2: (in, out), logits: (out,), labels: (out,) in {0, 1}
#     c = W * h_below[:, None]               # (in, out)
#     logits = c.sum(axis=0)
#     logits_wo = logits[None, :] - c        # (in, out)
    
#     log_probs = (
#         target_activations * jax.nn.log_sigmoid(logits) +
#         (1 - target_activations) * jax.nn.log_sigmoid(-logits)     # (out,)
#     )
#     log_probs_wo = (
#         target_activations * jax.nn.log_sigmoid(logits_wo) +
#         (1 - target_activations) * jax.nn.log_sigmoid(-logits_wo)  # (in, out)
#     )

#     # Sum BCE across outputs (standard multi-label reduction)
#     cross_entropy = -log_probs
#     cross_entropy_wo = -log_probs_wo
    
#     U_conn = cross_entropy_wo - cross_entropy[None, :] # (in, out)
#     # jax.debug.print("Number of 0s in U_conn: {}", jnp.sum(U_conn.sum(axis=0) == 0))
#     if mask is not None:
#         U_conn *= mask[None, :]
#         # jax.debug.print("New: {}", jnp.sum(U_conn.sum(axis=0) == 0))
   
    
#     U = jnp.sum(U_conn, axis=1) # (in,)

#     return U


# def propagate_utility_flip(h_below, W, target_activations):
#     """
#     Distribute utility from upper layer to lower layer using flip counterfactuals.
    
#     For each lower-layer unit i, computes how much the BCE loss (of upper-layer
#     pre-activations against target_activations) would change if h_below[i] were
#     flipped (0 <-> 1). Works for dead units too, unlike the LOO version.
    
#     Only works for LTUs (h_below in {0, 1}).
#     """
#     # Pre-activations of the upper layer
#     z = h_below @ W                                   # (out,)
    
#     # Counterfactual pre-activations when h_below[i] is flipped (0->1, 1->0)
#     flip = 1 - 2 * h_below                            # (in,) — +1 if dead, -1 if active
#     z_flip = z[None, :] + flip[:, None] * W           # (in, out)
    
#     # BCE against target_activations, treating each upper unit as an independent
#     # binary classifier with pre-activation z and target target_activations
#     log_probs = (
#         target_activations * jax.nn.log_sigmoid(z) +
#         (1 - target_activations) * jax.nn.log_sigmoid(-z)
#     )                                                 # (out,)
#     log_probs_flip = (
#         target_activations * jax.nn.log_sigmoid(z_flip) +
#         (1 - target_activations) * jax.nn.log_sigmoid(-z_flip)
#     )                                                 # (in, out)
    
#     cross_entropy = -log_probs                        # (out,)
#     cross_entropy_flip = -log_probs_flip              # (in, out)
    
#     # Sum BCE across upper units (standard multi-label reduction)
#     U_conn = cross_entropy_flip - cross_entropy[None, :]  # (in, out)
#     U = jnp.sum(U_conn, axis=1)                           # (in,)
    
#     return U



# def _scan_step(carry, data):
#     W1, W2, W3, mask1, mask2, ut1, ut2 = carry
#     x, label = data

#     logits, h1, h2 = forward(x, W1, W2, W3, mask1, mask2)
#     correct = (jnp.argmax(logits) == label).astype(jnp.float32)

#     # ====================== V1 ======================
#     # Works well
    
#     # U2 = compute_output_utility(h2, W3, logits, label)
#     # U2 = jnp.where(mask2 > 0.0, U2, -jnp.inf)
    
#     # # Target activation is 1 when unit is active, its utility is positive, and it's not pruned
#     # # Target is 0 otherwise
#     # # Note this could be simplified to U2 > 0 because U2 > 0 implies h2 > 0
#     # target_activations = jnp.where(
#     #     (h2 > 0.0) & (U2 > 0.0) & (mask2 > 0.0),
#     #     1.0, 0.0,
#     # )
    
#     # mask = U2 != 0.0
#     # U1 = propagate_utility(h1, W2, target_activations, U2, mask)
#     # U1 = jnp.where(mask1 > 0.0, U1, -jnp.inf)
    
    
#     # ====================== Using flip-based utility ======================
#     # Terrible performance
    
#     # U2 = compute_utility_flip(h2, W3, logits, label)
#     # U2 = jnp.where(mask2 > 0.0, U2, -jnp.inf)
    
#     # target_activations = jnp.where(
#     #     (((h2 > 0.0) & (U2 > 0.0) & (mask2 > 0.0)) |
#     #      ((h2 == 0.0) & (U2 < 0.0) & (mask2 > 0.0))),
#     #     1.0, 0.0,
#     # )
    
#     # U1 = propagate_utility_flip(h1, W2, target_activations)
#     # U1 = jnp.where(mask1 > 0.0, U1, -jnp.inf)
    
    
#     # ====================== Compination of v1 and flip based utility ======================
#     # Bad performance
    
#     # U2 = compute_output_utility(h2, W3, logits, label)
#     # U2 = jnp.where(mask2 > 0.0, U2, -jnp.inf)
#     # U2_flip = compute_utility_flip(h2, W3, logits, label)
    
#     # target_activations = jnp.where(
#     #     (((h2 > 0.0) & (U2_flip > 0.0) & (mask2 > 0.0)) |
#     #      ((h2 == 0.0) & (U2_flip < 0.0) & (mask2 > 0.0))),
#     #     1.0, 0.0,
#     # )
    
#     # U1 = propagate_utility(h1, W2, target_activations, U2)
#     # U1 = jnp.where(mask1 > 0.0, U1, -jnp.inf)
    
    
#     # ====================== V3 ======================
#     # Works really really well
    
#     U2 = compute_output_utility(h2, W3, logits, label)
#     U2 = jnp.where(mask2 > 0.0, U2, -jnp.inf)
#     U2_flip = compute_utility_flip(h2, W3, logits, label)

#     # Target = 1 when unit should be on (either case)
#     should_be_on = (
#         ((h2 > 0.0) & (U2_flip > 0.0)) |
#         ((h2 == 0.0) & (U2_flip < 0.0))
#     ) & (mask2 > 0.0)

#     # Unit is "informative" only when its current state is wrong or clearly right
#     # i.e., skip dead units that are correctly dead (the noise case)
#     informative = (
#         (h2 > 0.0) |                           # active units: always informative via LOO
#         ((h2 == 0.0) & (U2_flip < 0.0))        # dead units: only if they "should be on"
#     ) & (mask2 > 0.0)

#     target_activations = should_be_on.astype(jnp.float32)

#     U1 = propagate_utility(h1, W2, target_activations, U2, informative)
#     # Mask out contributions from uninformative layer-2 units
#     U1 = jnp.where(mask1 > 0.0, U1, -jnp.inf)
    
    
    

#     ut2 = ut2 * TRACE_DECAY + U2 * (1 - TRACE_DECAY)
#     ut1 = ut1 * TRACE_DECAY + U1 * (1 - TRACE_DECAY)

#     carry = (W1, W2, W3, mask1, mask2, ut1, ut2)
#     return carry, correct


# scan_chunk = jax.jit(
#     lambda carry, data: jax.lax.scan(_scan_step, carry, data, unroll=SCAN_UNROLL)
# )

# %%
def compute_remove_utility(h, W, pre_act, target, output_mask=None):
    """
    Utility of each unit in `h` based on loss change if that unit were removed.
    
    - `pre_act`: upper-layer pre-activation
    - `target`: label (int) for softmax CE, or target activations (float) for BCE
    - `output_mask`: optional (out,) mask to zero out contributions from specific upper units
    """
    pre_act_removed = pre_act[None, :] - h[:, None] * W       # (in, out)
    lp      = target * jax.nn.log_sigmoid(pre_act)      + (1 - target) * jax.nn.log_sigmoid(-pre_act)
    lp_removed = target * jax.nn.log_sigmoid(pre_act_removed) + (1 - target) * jax.nn.log_sigmoid(-pre_act_removed)
    U_per = (-lp_removed) - (-lp[None, :])                    # (in, out)
    if output_mask is not None:
        U_per = U_per * output_mask[None, :]
    return jnp.sum(U_per, axis=1)                          # (in,)

# %%
# # def compute_remove_utility(h, W, pre_act, target, binary_target=False, output_mask=None):
# #     """
# #     Utility of each unit in `h` based on loss change if that unit were removed.
    
# #     - `pre_act`: upper-layer pre-activation
# #     - `target`: label (int) for softmax CE, or target activations (float) for BCE
# #     - `binary_target`: True → per-output BCE summed across outputs; False → softmax CE on label
# #     - `output_mask`: optional (out,) mask to zero out contributions from specific upper units
# #     """
# #     pre_act_removed = pre_act[None, :] - h[:, None] * W       # (in, out)

# #     if binary_target:
# #         lp      = target * jax.nn.log_sigmoid(pre_act)      + (1 - target) * jax.nn.log_sigmoid(-pre_act)
# #         lp_removed = target * jax.nn.log_sigmoid(pre_act_removed) + (1 - target) * jax.nn.log_sigmoid(-pre_act_removed)
# #         U_per = (-lp_removed) - (-lp[None, :])                    # (in, out)
# #         if output_mask is not None:
# #             U_per = U_per * output_mask[None, :]
# #         return jnp.sum(U_per, axis=1)                          # (in,)
    
# #     else:
# #         lp      = jax.nn.log_softmax(pre_act)
# #         lp_removed = jax.nn.log_softmax(pre_act_removed, axis=1)
# #         return -lp_removed[:, target] - (-lp[target])             # (in,)

# # def compute_remove_utility(h, W, pre_act, target, output_mask=None):
# #     """
# #     Utility of each weight in `W` based on loss change if that weight were removed.
    
# #     - `pre_act`: upper-layer pre-activation
# #     - `target`: label (int) for softmax CE, or target activations (float) for BCE
# #     - `output_mask`: optional (out,) mask to zero out contributions from specific upper units
# #     """
# #     pre_act_removed = pre_act[None, :] - h[:, None] * W       # (in, out)
# #     lp      = target * jax.nn.log_sigmoid(pre_act)      + (1 - target) * jax.nn.log_sigmoid(-pre_act)
# #     lp_removed = target * jax.nn.log_sigmoid(pre_act_removed) + (1 - target) * jax.nn.log_sigmoid(-pre_act_removed)
# #     U_per = (-lp_removed) - (-lp[None, :])                    # (in, out)
# #     if output_mask is not None:
# #         U_per = U_per * output_mask[None, :]
# #     return U_per  


# # # Version of softmax CE utility that works for per-connection utilities
# # def softmax_ce_utility(W, M, x, y, logits):
# #     p = jax.nn.softmax(logits, axis=-1).reshape(-1)          # (OUT,)
# #     y_match = jax.nn.one_hot(y, num_classes=10).reshape(-1)
# #     d = -x[:, None] * W                                      # (IN, OUT)
# #     U = -d * y_match[None, :] + jnp.log1p(p[None, :] * jnp.expm1(d))
# #     return U * M


# def forward(x, W1, W2, W3, mask1, mask2):
#     z1 = x @ W1
#     h1 = ltu(z1) * mask1
#     z2 = h1 @ W2
#     h2 = ltu(z2) * mask2
#     logits = h2 @ W3
#     return logits, h1, h2


# def compute_flip_utility(h, W, pre_act, target, binary_target=False, output_mask=None):
#     """
#     Utility of each unit in `h` based on loss change if that unit were flipped (0<->1).
    
#     - `pre_act`: upper-layer pre-activation
#     - `target`: label (int) for softmax CE, or target activations (float) for BCE
#     - `binary_target`: True → per-output BCE summed across outputs; False → softmax CE on label
#     - `output_mask`: optional (out,) mask to zero out contributions from specific upper units
#     """
#     flip = 1 - 2 * h
#     pre_act_flip = pre_act[None, :] + flip[:, None] * W       # (in, out)

#     if binary_target:
#         lp      = target * jax.nn.log_sigmoid(pre_act)      + (1 - target) * jax.nn.log_sigmoid(-pre_act)
#         lp_flip = target * jax.nn.log_sigmoid(pre_act_flip) + (1 - target) * jax.nn.log_sigmoid(-pre_act_flip)
#         U_per = (-lp_flip) - (-lp[None, :])                    # (in, out)
#         if output_mask is not None:
#             U_per = U_per * output_mask[None, :]
#         return jnp.sum(U_per, axis=1)                          # (in,)
    
#     else:
#         lp      = jax.nn.log_softmax(pre_act)
#         lp_flip = jax.nn.log_softmax(pre_act_flip, axis=1)
#         return -lp_flip[:, target] - (-lp[target])             # (in,)
    

# def compute_targets(h, U_flip, mask):
#     """Target = better of {current, flipped}. Informative = active or should-be-active."""
#     should_flip = U_flip < 0
#     target = jnp.where(should_flip, 1.0 - h, h) * mask
#     informative = ((h > 0.0) | (target > 0.0)) & (mask > 0.0)
#     return target, informative


# def _scan_step(carry, data):
#     W1, W2, W3, mask1, mask2, ut1, ut2 = carry
#     x, label = data

#     logits, h1, h2 = forward(x, W1, W2, W3, mask1, mask2)
#     correct = (jnp.argmax(logits) == label).astype(jnp.float32)

#     # Output layer: flip utility, then derive LOO trace and targets
#     U2_flip = compute_flip_utility(h2, W3, logits, label, binary_target=False)
#     target2, informative2 = compute_targets(h2, U2_flip, mask2)
#     U2 = jnp.where(h2 > 0, U2_flip, 0.0)   # recovers LOO utility

#     # Propagate to hidden layer
#     z2 = h1 @ W2
#     U1_flip = compute_flip_utility(h1, W2, z2, target2, binary_target=True, output_mask=informative2)
#     U1 = jnp.where(h1 > 0, U1_flip, 0.0)

#     # Mask pruned units out of the traces
#     U1 = jnp.where(mask1 > 0.0, U1, -jnp.inf)
#     U2 = jnp.where(mask2 > 0.0, U2, -jnp.inf)

#     ut1 = ut1 * TRACE_DECAY + U1 * (1 - TRACE_DECAY)
#     ut2 = ut2 * TRACE_DECAY + U2 * (1 - TRACE_DECAY)

#     carry = (W1, W2, W3, mask1, mask2, ut1, ut2)
#     return carry, correct


# scan_chunk = jax.jit(
#     lambda carry, data: jax.lax.scan(_scan_step, carry, data, unroll=SCAN_UNROLL)
# )

# %%
def forward(x, W1, W2, W3, mask1, mask2):
    z1 = x @ W1
    h1 = ltu(z1) * mask1
    z2 = h1 @ W2
    h2 = ltu(z2) * mask2
    logits = h2 @ W3
    return logits, h1, h2


def compute_flip_utility(h, W, pre_act, target, output_mask=None):
    """
    Utility of each unit in `h` based on loss change if that unit were flipped (0<->1).
    
    - `pre_act`: upper-layer pre-activation
    - `target`: label (int) for softmax CE, or target activations (float) for BCE
    - `output_mask`: optional (out,) mask to zero out contributions from specific upper units
    """
    flip = 1 - 2 * h
    pre_act_flip = pre_act[None, :] + flip[:, None] * W       # (in, out)

    lp      = target * jax.nn.log_sigmoid(pre_act)      + (1 - target) * jax.nn.log_sigmoid(-pre_act)
    lp_flip = target * jax.nn.log_sigmoid(pre_act_flip) + (1 - target) * jax.nn.log_sigmoid(-pre_act_flip)
    U_per = (-lp_flip) - (-lp[None, :])                    # (in, out)
    if output_mask is not None:
        U_per = U_per * output_mask[None, :]
    return jnp.sum(U_per, axis=1)                          # (in,)1


def compute_targets(h, U_flip, mask):
    """Target = better of {current, flipped}. Informative = active or should-be-active."""
    should_flip = U_flip < 0
    target = jnp.where(should_flip, 1.0 - h, h) * mask
    informative = ((h > 0.0) | (target > 0.0)) & (mask > 0.0)
    return target, informative


def _scan_step(carry, data):
    W1, W2, W3, mask1, mask2, ut1, ut2 = carry
    x, label = data

    logits, h1, h2 = forward(x, W1, W2, W3, mask1, mask2)
    correct = (jnp.argmax(logits) == label).astype(jnp.float32)

    # Output layer: flip utility, then derive LOO trace and targets
    l2_targets = jax.nn.one_hot(label, num_classes=OUTPUT_SIZE)
    U2_flip = compute_flip_utility(h2, W3, logits, l2_targets)
    target2, informative2 = compute_targets(h2, U2_flip, mask2)
    U2 = jnp.where(h2 > 0, U2_flip, 0.0)   # recovers LOO utility
    
    # Version for per-connection utilities
    # U2 = softmax_ce_utility(W3, mask2, h2, label, logits)
    # U2 = U2.sum(axis=1)

    # Propagate to hidden layer
    z2 = h1 @ W2
    U1_flip = compute_flip_utility(h1, W2, z2, target2, output_mask=informative2)
    U1 = jnp.where(h1 > 0, U1_flip, 0.0)

    # Mask pruned units out of the traces
    U1 = jnp.where(mask1 > 0.0, U1, -jnp.inf)
    U2 = jnp.where(mask2 > 0.0, U2, -jnp.inf)

    ut1 = ut1 * TRACE_DECAY + U1 * (1 - TRACE_DECAY)
    ut2 = ut2 * TRACE_DECAY + U2 * (1 - TRACE_DECAY)

    carry = (W1, W2, W3, mask1, mask2, ut1, ut2)
    return carry, correct


scan_chunk = jax.jit(
    lambda carry, data: jax.lax.scan(_scan_step, carry, data, unroll=SCAN_UNROLL)
)

# %%
# ── Main loop ─────────────────────────────────────────────────────────
assert N_STEPS % PRUNE_EVERY == 0
assert PRINT_EVERY % PRUNE_EVERY == 0
n_prune_events = N_STEPS // PRUNE_EVERY
chunks_per_print = PRINT_EVERY // PRUNE_EVERY

all_corrects = []
n_active1_history = []
n_active2_history = []

rng = np.random.RandomState(SEED)
epoch_order = rng.permutation(len(all_labels_np))
epoch_pos = 0

def get_chunk(size):
    global epoch_order, epoch_pos
    indices = []
    remaining = size
    while remaining > 0:
        avail = len(epoch_order) - epoch_pos
        take = min(avail, remaining)
        indices.append(epoch_order[epoch_pos:epoch_pos + take])
        epoch_pos += take
        remaining -= take
        if epoch_pos >= len(epoch_order):
            epoch_order = rng.permutation(len(all_labels_np))
            epoch_pos = 0
    indices = np.concatenate(indices)
    return all_images_np[indices], all_labels_np[indices]

carry = (W1, W2, W3, mask1, mask2, utility_trace1, utility_trace2)

for prune_idx in range(n_prune_events):
    images_chunk, labels_chunk = get_chunk(PRUNE_EVERY)
    data = (jnp.array(images_chunk), jnp.array(labels_chunk))

    carry, corrects = scan_chunk(carry, data)
    all_corrects.append(np.array(corrects))

    W1, W2, W3, mask1, mask2, utility_trace1, utility_trace2 = carry
    n_active1 = int(mask1.sum())
    n_active2 = int(mask2.sum())
    n_active1_history.append(n_active1)
    n_active2_history.append(n_active2)

    # Prune the single lowest-utility unit across both layers
    score1 = jnp.where(mask1 > 0.5, utility_trace1, jnp.inf)
    score2 = jnp.where(mask2 > 0.5, utility_trace2, jnp.inf)
    min1 = jnp.min(score1)
    min2 = jnp.min(score2)

    can_prune1 = n_active1 > 1
    can_prune2 = False # n_active2 > 1

    if can_prune1 or can_prune2:
        prune_layer1 = can_prune1 and (not can_prune2 or min1 <= min2)
        if prune_layer1:
            worst = jnp.argmin(score1)
            mask1 = mask1.at[worst].set(0.0)
        else:
            worst = jnp.argmin(score2)
            mask2 = mask2.at[worst].set(0.0)

        if RESET_TRACES_ON_PRUNE:
            utility_trace1 = jnp.zeros(HIDDEN1_SIZE)
            utility_trace2 = jnp.zeros(HIDDEN2_SIZE)

    carry = (W1, W2, W3, mask1, mask2, utility_trace1, utility_trace2)

    step_num = (prune_idx + 1) * PRUNE_EVERY
    if step_num % PRINT_EVERY == 0:
        recent_chunks = all_corrects[-chunks_per_print:]
        recent_acc = float(np.concatenate(recent_chunks).mean()) * 100
        print(f'Step {step_num:>7d} | L1: {n_active1:>4d} | L2: {n_active2:>4d} | '
              f'Acc: {recent_acc:.1f}%')

print(f'\nDone. Active units — L1: {int(mask1.sum())} / {HIDDEN1_SIZE}, '
      f'L2: {int(mask2.sum())} / {HIDDEN2_SIZE}')
# Out:
# (10,)
# (10,)
# Step    5000 | L1: 3191 | L2:   10 | Acc: 9.2%
# Step   10000 | L1: 3181 | L2:   10 | Acc: 8.5%
# Step   15000 | L1: 3171 | L2:   10 | Acc: 8.1%
# Step   20000 | L1: 3161 | L2:   10 | Acc: 7.1%
# Step   25000 | L1: 3151 | L2:   10 | Acc: 8.2%
# Step   30000 | L1: 3141 | L2:   10 | Acc: 9.1%
# Step   35000 | L1: 3131 | L2:   10 | Acc: 10.1%
# Step   40000 | L1: 3121 | L2:   10 | Acc: 10.9%
# Step   45000 | L1: 3111 | L2:   10 | Acc: 11.3%
# Step   50000 | L1: 3101 | L2:   10 | Acc: 12.2%
# Step   55000 | L1: 3091 | L2:   10 | Acc: 13.7%
# Step   60000 | L1: 3081 | L2:   10 | Acc: 13.7%
# Step   65000 | L1: 3071 | L2:   10 | Acc: 15.6%
# Step   70000 | L1: 3061 | L2:   10 | Acc: 17.4%
# Step   75000 | L1: 3051 | L2:   10 | Acc: 18.7%
# Step   80000 | L1: 3041 | L2:   10 | Acc: 17.9%
# Step   85000 | L1: 3031 | L2:   10 | Acc: 19.6%
# Step   90000 | L1: 3021 | L2:   10 | Acc: 20.4%
# Step   95000 | L1: 3011 | L2:   10 | Acc: 22.4%
# ...

# %%
# ── Plot ───────────────────────────────────────────────────────────────
acc_per_interval = [chunk.mean() * 100 for chunk in all_corrects]
interval_centers = [(i + 0.5) * PRUNE_EVERY for i in range(len(acc_per_interval))]

fig, ax1 = plt.subplots(figsize=(12, 5))

color_acc = 'tab:blue'
ax1.plot(interval_centers, acc_per_interval, color=color_acc, linewidth=1.5, label='Accuracy')
ax1.set_xlabel('Step')
ax1.set_ylabel('Accuracy (%)', color=color_acc)
ax1.tick_params(axis='y', labelcolor=color_acc)
ax1.set_ylim(0, 100)
ax1.grid(True, alpha=0.3)

ax2 = ax1.twinx()
ax2.plot(interval_centers, n_active1_history, color='tab:red', linewidth=1.5,
         linestyle='--', label='L1 active')
ax2.plot(interval_centers, n_active2_history, color='tab:orange', linewidth=1.5,
         linestyle=':', label='L2 active')
ax2.set_ylabel('Active hidden units')

fig.suptitle('Learning by Pruning — 3-Layer MNIST (no weight updates)', fontsize=14)
fig.legend(loc='upper right', bbox_to_anchor=(0.88, 0.88))
fig.tight_layout()
plt.show()
