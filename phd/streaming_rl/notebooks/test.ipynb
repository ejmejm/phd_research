# %%
import torch
import numpy as np
import gymnasium as gym
from stable_baselines3.common.atari_wrappers import (
    EpisodicLifeEnv,
    FireResetEnv,
    MaxAndSkipEnv,
    NoopResetEnv,
)

from phd.streaming_rl.core.algorithms.stream_q import StreamQ
from phd.streaming_rl.core.processing import NormalizeObservation, ScaleReward

# %%
def agent_env_interaction(env_name='PongNoFrameskip-v4', seed=0, lr=1.0, gamma=0.99, lamda=0.8, total_steps=10_000, epsilon_target=0.01, epsilon_start=1.0, exploration_fraction=0.05, kappa_value=2.0, debug=True, save_agent=True, update_agent=True, load_agent=None, render=False):
    torch.manual_seed(seed); np.random.seed(seed)
    env = gym.make(env_name, render_mode="rgb_array")
    env = gym.wrappers.RecordEpisodeStatistics(env)
    env = NoopResetEnv(env, noop_max=30)
    env = MaxAndSkipEnv(env, skip=4)
    env = EpisodicLifeEnv(env)
    if "FIRE" in env.unwrapped.get_action_meanings():
        env = FireResetEnv(env)
    env = gym.wrappers.ResizeObservation(env, (84, 84))
    env = gym.wrappers.GrayScaleObservation(env)
    env = NormalizeObservation(env)
    env = gym.wrappers.FrameStack(env, 4)
    env = ScaleReward(env, gamma=gamma)
    agent = StreamQ(n_actions=env.action_space.n, lr=lr, gamma=gamma, lamda=lamda, epsilon_target=epsilon_target, epsilon_start=epsilon_start, exploration_fraction=exploration_fraction, total_steps=total_steps, kappa_value=kappa_value)

    # if render:
    #   from pyvirtualdisplay import Display
    #   virtual_display = Display(visible=0, size=(320, 240))
    #   virtual_display.start()

    if load_agent is not None:
        agent.load_state_dict(torch.load(load_agent+"/seed_{}.pth".format(seed), weights_only=False))
        reward_stats, obs_stats = pickle.load(open(load_agent+"/stats_data_{}.pkl".format(seed), "rb"))
        env.obs_stats.mean = obs_stats.mean
        env.obs_stats.var = obs_stats.var
        env.obs_stats.count = obs_stats.count
        env.obs_stats.p = obs_stats.p
        env.reward_stats.mean = reward_stats.mean
        env.reward_stats.var = reward_stats.var
        env.reward_stats.count = reward_stats.count
        env.reward_stats.p = reward_stats.p

    if debug:
        print("seed: {}".format(seed), "env: {}".format(env.spec.id))

    returns, term_time_steps, frames = [], [], []
    s, _ = env.reset(seed=seed)
    episode_num = 1
    for t in range(1, total_steps+1):
        a, is_nongreedy = agent.sample_action(s)
        s_prime, r, terminated, _, info = env.step(a)
        if update_agent:
            agent.update_params(s, a, r, s_prime, terminated, is_nongreedy)
        s = s_prime
        if render:
            if t % 4 == 0:
                frame = env.render()
                frames.append(frame)
        if info and "episode" in info:
            if debug:
                print("Episodic Return: {}, Time Step {}, Episode Number {}, Epsilon {}".format(info['episode']['r'][0], t, episode_num, agent.epsilon))
            returns.append(info['episode']['r'][0])
            term_time_steps.append(t)
            s, _ = env.reset()
            episode_num += 1
    env.close()

    if save_agent:
        save_dir = "data_stream_q_{}".format(env.spec.id)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        with open(os.path.join(save_dir, "seed_{}.pkl".format(seed)), "wb") as f:
            pickle.dump((returns, term_time_steps, env_name), f)
        save_dir = "stream_q_{}".format(env.spec.id)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        torch.save(agent.state_dict(), os.path.join(save_dir, "seed_{}.pth".format(seed)))
        reward_stats = env.reward_stats
        obs_stats = env.obs_stats
        with open(os.path.join(save_dir, "stats_data_{}.pkl".format(seed)), "wb") as f:
            pickle.dump((reward_stats, obs_stats), f)

    return frames

# %%
agent_env_interaction(env_name='PongNoFrameskip-v4',
                      seed=0,
                      lr=1.0,
                      gamma=0.99,
                      lamda=0.8,
                      total_steps=300_000,
                      epsilon_target=0.01,
                      epsilon_start=1.0,
                      exploration_fraction=0.05,
                      kappa_value=2.0,
                      debug=True,
                      save_agent=True,
                      update_agent=True,
)
# Out:
# seed: 0 env: PongNoFrameskip-v4
# /tmp/ipykernel_1325990/3991727647.py:49: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   x = torch.tensor(np.array(x), dtype=torch.float)
# /tmp/ipykernel_1325990/3991727647.py:71: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   s, a, r, s_prime, done_mask = torch.tensor(np.array(s), dtype=torch.float), torch.tensor([a], dtype=torch.int).squeeze(0), \
# /tmp/ipykernel_1325990/3991727647.py:72: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   torch.tensor(np.array(r)), torch.tensor(np.array(s_prime), dtype=torch.float), \
# Episodic Return: -20.0, Time Step 891, Episode Number 1, Epsilon 0.941194
# Episodic Return: -21.0, Time Step 1672, Episode Number 2, Epsilon 0.889648
# Episodic Return: -20.0, Time Step 2605, Episode Number 3, Epsilon 0.82807
# Episodic Return: -21.0, Time Step 3388, Episode Number 4, Epsilon 0.776392
# Episodic Return: -21.0, Time Step 4256, Episode Number 5, Epsilon 0.719104
# Episodic Return: -21.0, Time Step 5040, Episode Number 6, Epsilon 0.66736
# Episodic Return: -21.0, Time Step 6133, Episode Number 7, Epsilon 0.5952219999999999
# Episodic Return: -21.0, Time Step 7030, Episode Number 8, Epsilon 0.5360199999999999
# Episodic Return: -21.0, Time Step 7847, Episode Number 9, Epsilon 0.4820979999999999
# Episodic Return: -21.0, Time Step 8845, Episode Number 10, Epsilon 0.41623
# Episodic Return: -21.0, Time Step 9660, Episode Number 11, Epsilon 0.36244
# Episodic Return: -19.0, Time Step 10594, Episode Number 12, Epsilon 0.30079599999999995
# Episodic Return: -21.0, Time Step 11590, Episode Number 13, Epsilon 0.23505999999999994
# Episodic Return: -21.0, Time Step 12473, Episode Number 14, Epsilon 0.17678199999999988
# Episodic Return: -20.0, Time Step 13387, Episode Number 15, Epsilon 0.11645799999999995
# Episodic Return: -20.0, Time Step 14246, Episode Number 16, Epsilon 0.05976399999999993
# Episodic Return: -21.0, Time Step 15274, Episode Number 17, Epsilon 0.01
# Episodic Return: -21.0, Time Step 16155, Episode Number 18, Epsilon 0.01
# Episodic Return: -21.0, Time Step 17001, Episode Number 19, Epsilon 0.01
# Episodic Return: -21.0, Time Step 17759, Episode Number 20, Epsilon 0.01
# Episodic Return: -21.0, Time Step 18546, Episode Number 21, Epsilon 0.01
# Episodic Return: -18.0, Time Step 19650, Episode Number 22, Epsilon 0.01
# Episodic Return: -21.0, Time Step 20407, Episode Number 23, Epsilon 0.01
# Episodic Return: -21.0, Time Step 21168, Episode Number 24, Epsilon 0.01
# Episodic Return: -21.0, Time Step 225198, Episode Number 265, Epsilon 0.01
# Episodic Return: -20.0, Time Step 226065, Episode Number 266, Epsilon 0.01
# Episodic Return: -20.0, Time Step 227050, Episode Number 267, Epsilon 0.01
# Episodic Return: -18.0, Time Step 228195, Episode Number 268, Epsilon 0.01
# Episodic Return: -21.0, Time Step 228978, Episode Number 269, Epsilon 0.01
# Episodic Return: -20.0, Time Step 229987, Episode Number 270, Epsilon 0.01
# Episodic Return: -18.0, Time Step 231102, Episode Number 271, Epsilon 0.01
# Episodic Return: -20.0, Time Step 231991, Episode Number 272, Epsilon 0.01
# Episodic Return: -19.0, Time Step 233083, Episode Number 273, Epsilon 0.01
# Episodic Return: -21.0, Time Step 234105, Episode Number 274, Epsilon 0.01
# Episodic Return: -19.0, Time Step 235146, Episode Number 275, Epsilon 0.01
# Episodic Return: -18.0, Time Step 236152, Episode Number 276, Epsilon 0.01
# Episodic Return: -19.0, Time Step 237215, Episode Number 277, Epsilon 0.01
# Episodic Return: -21.0, Time Step 238059, Episode Number 278, Epsilon 0.01
# Episodic Return: -20.0, Time Step 239137, Episode Number 279, Epsilon 0.01
# Episodic Return: -21.0, Time Step 240037, Episode Number 280, Epsilon 0.01
# Episodic Return: -21.0, Time Step 240869, Episode Number 281, Epsilon 0.01
# Episodic Return: -21.0, Time Step 241749, Episode Number 282, Epsilon 0.01
# Episodic Return: -20.0, Time Step 242803, Episode Number 283, Epsilon 0.01
# Episodic Return: -21.0, Time Step 243733, Episode Number 284, Epsilon 0.01
# Episodic Return: -19.0, Time Step 244814, Episode Number 285, Epsilon 0.01
# Episodic Return: -21.0, Time Step 245780, Episode Number 286, Epsilon 0.01
# Episodic Return: -19.0, Time Step 246786, Episode Number 287, Epsilon 0.01
# Episodic Return: -20.0, Time Step 247651, Episode Number 288, Epsilon 0.01
# Episodic Return: -20.0, Time Step 248514, Episode Number 289, Epsilon 0.01
# Episodic Return: -20.0, Time Step 249438, Episode Number 290, Epsilon 0.01
# Episodic Return: -20.0, Time Step 250364, Episode Number 291, Epsilon 0.01
# Episodic Return: -20.0, Time Step 251332, Episode Number 292, Epsilon 0.01
# Episodic Return: -20.0, Time Step 252226, Episode Number 293, Epsilon 0.01
# Episodic Return: -21.0, Time Step 253041, Episode Number 294, Epsilon 0.01
# Episodic Return: -20.0, Time Step 253906, Episode Number 295, Epsilon 0.01
# Episodic Return: -21.0, Time Step 255004, Episode Number 296, Epsilon 0.01
# Episodic Return: -21.0, Time Step 255843, Episode Number 297, Epsilon 0.01
# Episodic Return: -20.0, Time Step 256704, Episode Number 298, Epsilon 0.01
# Episodic Return: -20.0, Time Step 257601, Episode Number 299, Epsilon 0.01
# Episodic Return: -21.0, Time Step 258478, Episode Number 300, Epsilon 0.01
# Episodic Return: -20.0, Time Step 259330, Episode Number 301, Epsilon 0.01
# Episodic Return: -20.0, Time Step 260312, Episode Number 302, Epsilon 0.01
# Episodic Return: -20.0, Time Step 261253, Episode Number 303, Epsilon 0.01
# Episodic Return: -20.0, Time Step 262247, Episode Number 304, Epsilon 0.01
# Episodic Return: -21.0, Time Step 263171, Episode Number 305, Epsilon 0.01
# Episodic Return: -19.0, Time Step 264212, Episode Number 306, Epsilon 0.01
# Episodic Return: -20.0, Time Step 265117, Episode Number 307, Epsilon 0.01
# Episodic Return: -20.0, Time Step 265970, Episode Number 308, Epsilon 0.01
# Episodic Return: -19.0, Time Step 267064, Episode Number 309, Epsilon 0.01
# Episodic Return: -20.0, Time Step 268238, Episode Number 310, Epsilon 0.01
# Episodic Return: -19.0, Time Step 269302, Episode Number 311, Epsilon 0.01
# Episodic Return: -21.0, Time Step 270062, Episode Number 312, Epsilon 0.01
# Episodic Return: -18.0, Time Step 271419, Episode Number 313, Epsilon 0.01
# Episodic Return: -19.0, Time Step 272638, Episode Number 314, Epsilon 0.01
# Episodic Return: -19.0, Time Step 273718, Episode Number 315, Epsilon 0.01
# Episodic Return: -19.0, Time Step 274841, Episode Number 316, Epsilon 0.01
# Episodic Return: -21.0, Time Step 275771, Episode Number 317, Epsilon 0.01
# Episodic Return: -20.0, Time Step 276980, Episode Number 318, Epsilon 0.01
# Episodic Return: -20.0, Time Step 278015, Episode Number 319, Epsilon 0.01
# Episodic Return: -21.0, Time Step 279008, Episode Number 320, Epsilon 0.01
# Episodic Return: -20.0, Time Step 280148, Episode Number 321, Epsilon 0.01
# Episodic Return: -21.0, Time Step 280992, Episode Number 322, Epsilon 0.01
# Episodic Return: -21.0, Time Step 282051, Episode Number 323, Epsilon 0.01
# Episodic Return: -20.0, Time Step 282962, Episode Number 324, Epsilon 0.01
# Episodic Return: -20.0, Time Step 284033, Episode Number 325, Epsilon 0.01
# Episodic Return: -21.0, Time Step 284937, Episode Number 326, Epsilon 0.01
# Episodic Return: -20.0, Time Step 286064, Episode Number 327, Epsilon 0.01
# Episodic Return: -20.0, Time Step 287120, Episode Number 328, Epsilon 0.01
# Episodic Return: -20.0, Time Step 288120, Episode Number 329, Epsilon 0.01
# Episodic Return: -20.0, Time Step 289071, Episode Number 330, Epsilon 0.01
# Episodic Return: -20.0, Time Step 290031, Episode Number 331, Epsilon 0.01
# Episodic Return: -20.0, Time Step 291041, Episode Number 332, Epsilon 0.01
# Episodic Return: -20.0, Time Step 291923, Episode Number 333, Epsilon 0.01
# Episodic Return: -21.0, Time Step 292772, Episode Number 334, Epsilon 0.01
# Episodic Return: -21.0, Time Step 293556, Episode Number 335, Epsilon 0.01
# Episodic Return: -20.0, Time Step 294543, Episode Number 336, Epsilon 0.01
# Episodic Return: -21.0, Time Step 295584, Episode Number 337, Epsilon 0.01
# Episodic Return: -21.0, Time Step 296483, Episode Number 338, Epsilon 0.01
# Episodic Return: -20.0, Time Step 297485, Episode Number 339, Epsilon 0.01
# Episodic Return: -21.0, Time Step 298269, Episode Number 340, Epsilon 0.01
# Episodic Return: -20.0, Time Step 299437, Episode Number 341, Epsilon 0.01
# /home/ejmejm/miniconda3/envs/research/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.obs_stats to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_stats` for environment variables or `env.get_wrapper_attr('obs_stats')` that will search the reminding wrappers.
#   logger.warn(
# []
